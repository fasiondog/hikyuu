# %%
# %time from hikyuu.interactive import *
# Out:
# Initialize hikyuu_2.7.3_202601230127_RELEASE_macosx_arm64 ...
# 2026-01-23 01:30:12.536 [HKU-I] - current python version: 3.12.7 (main.cpp:74)
# 2026-01-23 01:30:14,069 [INFO] runing in interactive session [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:145) [hikyuu::hku_info]
# 2026-01-23 01:30:14,069 [INFO] running in jupyter [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:152) [hikyuu::hku_info]
# 2026-01-23 01:30:14.073 [HKU-I] - 插件路径: /Users/fasiondog/workspace/hku_plugin/hikyuu_plugin (StockManager.cpp:113)
# 2026-01-23 01:30:15.220 [HKU-I] - Using CLICKHOUSE BaseInfoDriver (BaseInfoDriver.cpp:57)
# 2026-01-23 01:30:15.241 [HKU-I] - 加载市场信息…… (StockManager.cpp:755)
# 2026-01-23 01:30:15.249 [HKU-I] - 加载证券类型信息…… (StockManager.cpp:773)
# 2026-01-23 01:30:15.255 [HKU-I] - 加载证券信息…… (StockManager.cpp:653)
# 2026-01-23 01:30:15.342 [HKU-I] - 加载权息数据…… (StockManager.cpp:792)
# 2026-01-23 01:30:15.501 [HKU-I] - 加载板块信息…… (StockManager.cpp:182)
# ...

# %%
k = get_kdata('sh000001', -100)

# %%
import pickle

with open("temp", 'wb') as f:
    pickle.dump(k, f)

# %%
hku_save(k, "temp")

# %%
k2 = hku_load("temp")

# %%
k2.plot()
