# %%
#%matplotlib inline
# %time from hikyuu.interactive import *

# %% [markdown]
# 1. Get stock objects globally
# ==========
#
# 1.1 Get a stock object
# -----------------
#
# Use the global management object sm, or use the function get_stock. The stock identifier format is "market code + stock code"; the market codes are: SH for the Shanghai market and SZ for the Shenzhen market.

# %%
#s = getStock('sh000001')
s = sm['sh000001']
print(s)

# %% [markdown]
# 1.2 Traverse all the stocks
# -----------------

# %%
i = 0
# Traverse all the stocks
for s in sm:
    i += 1
    #print(s)
print("Total number:", i)

len(sm)

# %% [markdown]
# 2. Traverse the stock objects through a block
# ================
#
# Use sm.get_block("block category", "block name") to get the corresponding block

# %%
blk = sm.get_block("指数板块", "沪深300")  # domain data: block names
print(len(blk))
# for s in blk:
#     if s.valid:
#         print(s)

# %% [markdown]
# 3. View the equity/dividend adjustment information
# =======

# %%
ws = sm['sz000001'].get_weight()
for w in ws:
    print(w)

# %%
ws.to_df()
