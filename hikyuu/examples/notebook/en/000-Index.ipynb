# %% [markdown]
# <img src="http://hikyuu.readthedocs.io/en/latest/_images/00000-title.png" align="left">

# %% [markdown]
# Hikyuu Quant Framework is an open-source C++/Python quantitative trading research framework for strategy analysis and backtesting. Its core idea is based on the current mature systematic trading method: the whole systematic trading strategy is abstracted into seven components, namely the market environment strategy, the system valid condition, the signal generator, the stop-loss / take-profit strategy, the money management strategy, the profit goal strategy and the slippage algorithm. You can build the strategy asset library of these components separately and combine them freely in practical research to observe the effectiveness and stability of the system as well as the effect of a single kind of strategy. On top of the system strategy, the trading object selection, the system strategy selection and the portfolio fund allocation are further encapsulated, so as to flexibly support higher-level strategy combinations.
#
# For more information, please visit: <https://hikyuu.org>

# %% [markdown]
# ## Getting Started
#
# * [001 Interactive tools](001-overview.ipynb?flush_cache=True)
# * [002 Getting stock objects](002-HowToGetStock.ipynb?flush_cache=True)
# * [003 Getting and plotting K-line data](003-HowToGetKDataAndDraw.ipynb?flush_cache=True)
# * [004 Calculating and plotting technical indicators](004-IndicatorOverview.ipynb?flush_cache=True)
# * [005 Plotting composite figures](005-Drawplot.ipynb?flush_cache=True)
# * [006 TradeManager applications](006-TradeManager.ipynb?flush_cache=True)
# * [007 System strategy demonstration](007-SystemDetails.ipynb?flush_cache=True)
# * [008 Serialization](008-Pickle.ipynb?flush_cache=True)
# * [009 Getting real-time daily data](009-RealData.ipynb?flush_cache=True)
# * [010 Portfolio](010-Portfolio.ipynb?flush_cache=True)

# %% [markdown]
# ## Examples
#
# * [Demo1](Demo/Demo1.ipynb?flush_cache=True)
# * [Demo2](Demo/Demo2.ipynb?flush_cache=True)
