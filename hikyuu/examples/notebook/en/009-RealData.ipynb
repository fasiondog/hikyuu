# %%
# %matplotlib inline
# %time from hikyuu.interactive import *
# Out:
# Initialize hikyuu_2.8.2_202609250345_RELEASE_macosx_arm64 ...
# 2026-09-25 13:34:44.922 [HKU-I] - current python version: 3.13.12 (main.cpp:77)
# 2026-09-25 13:34:46,128 [INFO] runing in interactive session [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:149) [hikyuu::hku_info]
# 2026-09-25 13:34:46,128 [INFO] running in jupyter [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:156) [hikyuu::hku_info]
# 2026-09-25 13:34:46.133 [HKU-I] - 插件路径: /Users/fasiondog/workspace/hku_plugin/hikyuu_plugin (StockManager.cpp:124)
# 2026-09-25 13:34:46.181 [HKU-I] - Using CLICKHOUSE BaseInfoDriver (BaseInfoDriver.cpp:56)
# 2026-09-25 13:34:46.208 [HKU-I] - 加载市场信息…… (StockManager.cpp:1050)
# 2026-09-25 13:34:46.220 [HKU-I] - 加载证券类型信息…… (StockManager.cpp:1067)
# 2026-09-25 13:34:46.230 [HKU-I] - 加载证券信息…… (StockManager.cpp:948)
# 2026-09-25 13:34:46.369 [HKU-I] - 加载权息数据…… (StockManager.cpp:1170)
# 2026-09-25 13:34:46.638 [HKU-I] - 加载板块信息…… (StockManager.cpp:214)
# ...

# %% [markdown]
# # Get the real-time daily data
#
# Currently only the real-time daily data is supported, using the function realtimeUpdate(source, delta=60). Among them, source supports 'qq' | 'qmt', and qq is used by default.
#
# **When using qq, you should control the interval between two data acquisitions (using the delta parameter, defaulting to 60s), so as not to put the ip on the blacklist of sina or qq.**

# %%
# %time realtime_update('qq')
# Out:
# Update completed! Update time: 2026-09-25 13:34:47.922853
# CPU times: user 414 ms, sys: 117 ms, total: 531 ms
# Wall time: 1.07 s
