# %%
# %matplotlib inline
# %time from hikyuu.interactive import *
from pylab import plot
# Out:
# Initialize hikyuu_2.8.2_202609250345_RELEASE_macosx_arm64 ...
# 2026-09-25 13:34:58.876 [HKU-I] - current python version: 3.13.12 (main.cpp:77)
# 2026-09-25 13:35:00,226 [INFO] runing in interactive session [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:149) [hikyuu::hku_info]
# 2026-09-25 13:35:00,226 [INFO] running in jupyter [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:156) [hikyuu::hku_info]
# 2026-09-25 13:35:00.229 [HKU-I] - 插件路径: /Users/fasiondog/workspace/hku_plugin/hikyuu_plugin (StockManager.cpp:124)
# 2026-09-25 13:35:00.260 [HKU-I] - Using CLICKHOUSE BaseInfoDriver (BaseInfoDriver.cpp:56)
# 2026-09-25 13:35:00.285 [HKU-I] - 加载市场信息…… (StockManager.cpp:1050)
# 2026-09-25 13:35:00.297 [HKU-I] - 加载证券类型信息…… (StockManager.cpp:1067)
# 2026-09-25 13:35:00.308 [HKU-I] - 加载证券信息…… (StockManager.cpp:948)
# 2026-09-25 13:35:00.465 [HKU-I] - 加载权息数据…… (StockManager.cpp:1170)
# 2026-09-25 13:35:00.775 [HKU-I] - 加载板块信息…… (StockManager.cpp:214)
# 2026-09-25 13:35:00.943 [HKU-I] - 加载K线数据…… (StockManager.cpp:221)
# 2026-09-25 13:35:00.943 [HKU-I] - 预加载 day K线数据至缓存 (最大数量: 100000)! (StockManager.cpp:395)
# 2026-09-25 13:35:00.943 [HKU-I] - 0.67 秒数据加载完毕. (StockManager.cpp:231)
# CPU times: user 2.37 s, sys: 202 ms, total: 2.58 s
# Wall time: 3.33 s

# %%
# Create a system strategy
# my_mm = MM_FixedCount(100)
my_mm = MM_Nothing()
my_sg = SG_Flex(EMA(CLOSE(), n=5), slow_n=10)
my_sys = SYS_Simple(sg=my_sg, mm=my_mm)

# %%
# Create a selector algorithm to select the trading system every day
# This is a fixed selector, i.e. the specified trading system is selected every day
# my_se = SE_Fixed([s for s in blocka if s.valid], my_sys)
my_se = SE_Fixed([s for s in sm.get_block("指数板块", "沪深300")], my_sys)

# %%
# Create an asset allocator to determine how to allocate the assets among the selected trading systems
# This creates an equal-weight asset allocator, i.e. allocating the funds among the selected systems with the same ratio
my_af = AF_EqualWeight()

# %%
# Create the portfolio
# Create an account starting from 2001-01-01 with an initial capital of 2,000,000. Since an equal-weight allocator is used, the remaining funds of the account are allocated equally among all the selected systems,
# If the initial capital is too small, each system will not have enough funds to complete the trades.
my_tm = crtTM(Datetime(200101010000), 2000000)
my_pf = PF_Simple(tm=my_tm, af=my_af, se=my_se)

# %%
# Run the portfolio
q = Query(-500)
# %time my_pf.run(Query(-500), 10)
# Out:
# CPU times: user 1.73 s, sys: 657 ms, total: 2.38 s
# Wall time: 9.01 s

# %%
x = my_tm.get_funds_curve(sm.get_trading_calendar(q))
PRICELIST(x).plot()

# %%
my_pf.performance()
# Out:
# <Axes: title={'center': '账户(SYS) 累积收益率'}>

# %%
my_tm
# Out:
# TradeManager {
#   params: params[precision(int): 2, save_action(bool): 1, support_borrow_cash(bool): 0, support_borrow_stock(bool): 0, ],
#   name: SYS,
#   init_date: 2001-01-01 00:00:00,
#   init_cash: 2000000.00,
#   firstDatetime: 2024-09-05 00:00:00,
#   lastDatetime: 2026-09-24 00:00:00,
#   TradeCostFunc: TradeCostFunc(TC_Zero, params[]),
#   current total funds: 2514686.51,
#   current cash: 2031021.51,
#   current market_value: 483665.00,
#   current short_market_value: 0.00,
#   current base_cash: 2000000.00,
#   current base_asset: 0.00,
#   current borrow_cash: 0.00,
#   current borrow_asset: 0.00,
#   Position:
#     证券代码 证券名称 建仓日期 持有天数 持有数量 投入资金 当前市值 当前收益 当前收益率 相对账户初始资金收益率
#     SH600023 浙能电力 2026-09-10 00:00:00 11 1700.00 8500.00 8738.00 238.00 2.80% 0.01%
#     SH600026 中远海能 2026-08-18 00:00:00 28 400.00 6701.00 8560.00 1859.00 27.74% 0.09%
#     SH600029 南方航空 2026-09-24 00:00:00 1 1700.00 8415.00 8262.00 -153.00 -1.82% -0.01%
#     SH600048 保利发展 2026-09-21 00:00:00 4 1600.00 8400.00 8896.00 496.00 5.90% 0.02%
#     SH600115 中国东航 2026-09-24 00:00:00 1 2500.00 8575.00 8375.00 -200.00 -2.33% -0.01%
#     SH600150 中国船舶 2026-08-27 00:00:00 21 200.00 6830.00 7618.00 788.00 11.54% 0.04%
#     SH600176 中国巨石 2026-09-11 00:00:00 10 200.00 8460.00 8612.00 152.00 1.80% 0.01%
#     SH600196 复星医药 2026-09-22 00:00:00 3 300.00 6861.00 6852.00 -9.00 -0.13% -0.00%
#     SH600233 圆通速递 2026-09-18 00:00:00 5 400.00 7108.00 7168.00 60.00 0.84% 0.00%
#     SH600276 恒瑞医药 2026-09-23 00:00:00 2 100.00 4559.00 4486.00 -73.00 -1.60% -0.00%
#     SH600426 华鲁恒升 2026-09-24 00:00:00 1 400.00 8100.00 7884.00 -216.00 -2.67% -0.01%
#     SH600438 通威股份 2026-09-23 00:00:00 2 700.00 8204.00 7784.00 -420.00 -5.12% -0.02%
#     SH600460 士兰微 2026-09-18 00:00:00 5 200.00 6500.00 6544.00 44.00 0.68% 0.00%
#     SH600482 中国动力 2026-09-22 00:00:00 3 200.00 7106.00 6850.00 -256.00 -3.60% -0.01%
#     SH600522 中天科技 2026-09-14 00:00:00 9 200.00 6768.00 6960.00 192.00 2.84% 0.01%
#     SH600584 长电科技 2026-09-21 00:00:00 4 100.00 7305.00 6878.00 -427.00 -5.85% -0.02%
#     SH600674 川投能源 2026-08-20 00:00:00 26 500.00 7740.00 8135.00 395.00 5.10% 0.02%
#     SH600845 宝信软件 2026-09-21 00:00:00 4 400.00 7196.00 7304.00 108.00 1.50% 0.01%
#     SH600886 国投电力 2026-09-24 00:00:00 1 500.00 7325.00 7430.00 105.00 1.43% 0.01%
#     SH600887 伊利股份 2026-09-21 00:00:00 4 300.00 7968.00 8070.00 102.00 1.28% 0.01%
#     SH600999 招商证券 2026-09-23 00:00:00 2 400.00 7200.00 6976.00 -224.00 -3.11% -0.01%
#     SH601088 中国神华 2026-09-24 00:00:00 1 100.00 4734.00 4803.00 69.00 1.46% 0.00%
#     SH601111 中国国航 2026-09-22 00:00:00 3 1400.00 8288.00 8134.00 -154.00 -1.86% -0.01%
#     SH601211 国泰海通 2026-09-23 00:00:00 2 400.00 7072.00 6884.00 -188.00 -2.66% -0.01%
#     SH601319 中国人保 2026-08-26 00:00:00 22 1100.00 7704.10 8877.00 1172.90 15.22% 0.06%
#     SH601328 交通银行 2026-08-20 00:00:00 26 1200.00 8520.00 9072.00 552.00 6.48% 0.03%
#     SH601360 三六零 2026-09-23 00:00:00 2 900.00 8217.00 8055.00 -162.00 -1.97% -0.01%
#     SH601377 兴业证券 2026-09-22 00:00:00 3 1400.00 8386.00 8218.00 -168.00 -2.00% -0.01%
#     SH601398 工商银行 2026-08-20 00:00:00 26 1100.00 8525.00 8943.00 418.00 4.90% 0.02%
#     SH601628 中国人寿 2026-09-23 00:00:00 2 200.00 7728.00 7486.00 -242.00 -3.13% -0.01%
#     SH601689 拓普集团 2026-09-23 00:00:00 2 100.00 4571.00 4644.00 73.00 1.60% 0.00%
#     SH601727 上海电气 2026-09-23 00:00:00 2 1300.00 8697.00 8528.00 -169.00 -1.94% -0.01%
#     SH601872 招商轮船 2026-09-04 00:00:00 15 400.00 7760.00 8372.00 612.00 7.89% 0.03%
#     SH601877 正泰电器 2026-09-23 00:00:00 2 300.00 7617.00 7470.00 -147.00 -1.93% -0.01%
#     SH601901 方正证券 2026-09-22 00:00:00 3 1200.00 8292.00 8088.00 -204.00 -2.46% -0.01%
#     SH601919 中远海控 2026-09-22 00:00:00 3 500.00 8340.00 8150.00 -190.00 -2.28% -0.01%
#     SH601988 中国银行 2026-08-18 00:00:00 28 1400.00 8184.00 9268.00 1084.00 13.25% 0.05%
#     SH601998 中信银行 2026-08-17 00:00:00 29 1000.00 7579.00 9010.00 1431.00 18.88% 0.07%
#     SH603019 中科曙光 2026-09-22 00:00:00 3 100.00 8690.00 8217.00 -473.00 -5.44% -0.02%
#     SH603288 海天味业 2026-09-24 00:00:00 1 200.00 6820.00 6786.00 -34.00 -0.50% -0.00%
#     SH603296 华勤技术 2026-09-18 00:00:00 5 100.00 8033.00 7911.00 -122.00 -1.52% -0.01%
#     SH603501 豪威集团 2026-09-22 00:00:00 3 100.00 8155.00 8140.00 -15.00 -0.18% -0.00%
#     SH688126 沪硅产业 2026-09-18 00:00:00 5 200.00 4872.00 4960.00 88.00 1.81% 0.00%
#     SZ000538 云南白药 2026-09-01 00:00:00 18 100.00 4925.20 4987.00 61.80 1.25% 0.00%
#     SZ000625 长安汽车 2026-09-22 00:00:00 3 1200.00 8580.00 8436.00 -144.00 -1.68% -0.01%
#     SZ000725 京东方Ａ 2026-09-21 00:00:00 4 1400.00 8400.00 8190.00 -210.00 -2.50% -0.01%
#     SZ001965 招商公路 2026-09-11 00:00:00 10 900.00 8757.00 8892.00 135.00 1.54% 0.01%
#     SZ001979 招商蛇口 2026-09-21 00:00:00 4 1200.00 8364.00 8616.00 252.00 3.01% 0.01%
#     SZ002049 紫光国微 2026-09-23 00:00:00 2 100.00 6186.00 6060.00 -126.00 -2.04% -0.01%
#     SZ002050 三花智控 2026-09-22 00:00:00 3 200.00 7314.00 7216.00 -98.00 -1.34% -0.00%
#     SZ002074 国轩高科 2026-09-22 00:00:00 3 300.00 8136.00 8028.00 -108.00 -1.33% -0.01%
#     SZ002179 中航光电 2026-09-11 00:00:00 10 200.00 6904.00 6848.00 -56.00 -0.81% -0.00%
#     SZ002241 歌尔股份 2026-09-22 00:00:00 3 300.00 7500.00 7182.00 -318.00 -4.24% -0.02%
#     SZ002422 科伦药业 2026-09-22 00:00:00 3 200.00 8440.00 7772.00 -668.00 -7.91% -0.03%
#     SZ002475 立讯精密 2026-09-24 00:00:00 1 100.00 5415.00 5200.00 -215.00 -3.97% -0.01%
#     SZ002594 比亚迪 2026-09-24 00:00:00 1 100.00 8570.00 8434.00 -136.00 -1.59% -0.01%
#     SZ300122 智飞生物 2026-09-23 00:00:00 2 600.00 8004.00 7806.00 -198.00 -2.47% -0.01%
#     SZ300316 晶盛机电 2026-09-21 00:00:00 4 200.00 8542.00 8140.00 -402.00 -4.71% -0.02%
#     SZ300413 芒果超媒 2026-09-22 00:00:00 3 400.00 7788.00 7600.00 -188.00 -2.41% -0.01%
#     SZ300442 润泽科技 2026-09-23 00:00:00 2 100.00 6601.00 6801.00 200.00 3.03% 0.01%
#     SZ300450 先导智能 2026-09-21 00:00:00 4 200.00 6478.00 6422.00 -56.00 -0.86% -0.00%
#     SZ300498 温氏股份 2026-09-22 00:00:00 3 500.00 7465.00 7255.00 -210.00 -2.81% -0.01%
#     SZ300628 亿联网络 2026-09-16 00:00:00 7 200.00 8080.00 8192.00 112.00 1.39% 0.01%
#     SZ301236 软通动力 2026-09-22 00:00:00 3 200.00 7696.00 7190.00 -506.00 -6.57% -0.03%
#   Short Position:
#   Borrow Stock:
# }

# %%
my_tm.get_position_list().to_df()
# Out:
#     证券代码  证券名称   开仓时间  持有天数  持仓数量  总投入资金    市值  \
# 0   SH600023  浙能电力 2026-09-10        15    1700.0      8500.0  8738.0
# 1   SH600026  中远海能 2026-08-18        38     400.0      6701.0  8560.0
# 2   SH600029  南方航空 2026-09-24         1    1700.0      8415.0  8262.0
# 3   SH600048  保利发展 2026-09-21         4    1600.0      8400.0  8896.0
# 4   SH600115  中国东航 2026-09-24         1    2500.0      8575.0  8375.0
# ..       ...       ...        ...       ...       ...         ...     ...
# 59  SZ300442  润泽科技 2026-09-23         2     100.0      6601.0  6801.0
# 60  SZ300450  先导智能 2026-09-21         4     200.0      6478.0  6422.0
# 61  SZ300498  温氏股份 2026-09-22         3     500.0      7465.0  7255.0
# 62  SZ300628  亿联网络 2026-09-16         9     200.0      8080.0  8192.0
# 63  SZ301236  软通动力 2026-09-22         3     200.0      7696.0  7190.0
#
#       收益  收益百分比  止损  目标价格 清仓时间  累计持仓数量  累计成本  \
# 0    238.0        2.80   0.0       NaN      NaT        1700.0       0.0
# 1   1859.0       27.74   0.0       NaN      NaT         500.0       0.0
# 2   -153.0       -1.82   0.0       NaN      NaT        1700.0       0.0
# 3    496.0        5.90   0.0       NaN      NaT        1600.0       0.0
# 4   -200.0       -2.33   0.0       NaN      NaT        2500.0       0.0
# ..     ...         ...   ...       ...      ...           ...       ...
# 59   200.0        3.03   0.0       NaN      NaT         100.0       0.0
# 60   -56.0       -0.86   0.0       NaN      NaT         200.0       0.0
# 61  -210.0       -2.81   0.0       NaN      NaT         500.0       0.0
# 62   112.0        1.39   0.0       NaN      NaT         200.0       0.0
# 63  -506.0       -6.57   0.0       NaN      NaT         200.0       0.0
#
#     累计风险  累计买入资金  累计卖出资金
# 0     8500.0        8500.0           0.0
# 1     8910.0        8910.0        2209.0
# 2     8415.0        8415.0           0.0
# 3     8400.0        8400.0           0.0
# 4     8575.0        8575.0           0.0
# ..       ...           ...           ...
# 59    6601.0        6601.0           0.0
# 60    6478.0        6478.0           0.0
# 61    7465.0        7465.0           0.0
# 62    8180.0        8180.0         100.0
# 63    7696.0        7696.0           0.0
#
# [64 rows x 17 columns]

# %%
my_tm.get_trade_list().to_df()
# Out:
#        证券代码  证券名称       日期 交易操作    计划价格    实际价格  \
# 0                         2001-01-01     INIT  2000000.00  2000000.00
# 1      SH600958  东方证券 2024-09-05      BUY        8.48        8.48
# 2      SH601916  浙商银行 2024-09-06      BUY        2.55        2.55
# 3      SZ000975  山金国际 2024-09-06      BUY       15.43       15.43
# 4      SZ000963  华东医药 2024-09-06      BUY       29.35       29.35
# ...         ...       ...        ...      ...         ...         ...
# 11104  SH600118  中国卫星 2026-09-24     SELL       57.63       57.63
# 11105  SH600930  华电新能 2026-09-24     SELL        3.90        3.90
# 11106  SH600104  上汽集团 2026-09-24     SELL       10.83       10.83
# 11107  SH601169  北京银行 2026-09-24     SELL        5.48        5.48
# 11108  SZ002142  宁波银行 2026-09-24     SELL       34.66       34.66
#
#        目标价格    数量  止损        现金  总成本  佣金  印花税  过户费  \
# 0           0.0     0.0   0.0  2000000.00     0.0   0.0     0.0     0.0
# 1           NaN   800.0   0.0  1993216.00     0.0   0.0     0.0     0.0
# 2           NaN  2700.0   0.0  1986331.00     0.0   0.0     0.0     0.0
# 3           NaN   400.0   0.0  1980159.00     0.0   0.0     0.0     0.0
# 4           NaN   200.0   0.0  1974289.00     0.0   0.0     0.0     0.0
# ...         ...     ...   ...         ...     ...   ...     ...     ...
# 11104       NaN   100.0   0.0  1998077.51     0.0   0.0     0.0     0.0
# 11105       NaN  2200.0   0.0  2006657.51     0.0   0.0     0.0     0.0
# 11106       NaN   800.0   0.0  2015321.51     0.0   0.0     0.0     0.0
# 11107       NaN  1600.0   0.0  2024089.51     0.0   0.0     0.0     0.0
# 11108       NaN   200.0   0.0  2031021.51     0.0   0.0     0.0     0.0
#
#        其它成本 来源 备注
# 0           0.0   --
# 1           0.0   SG
# 2           0.0   SG
# 3           0.0   SG
# 4           0.0   SG
# ...         ...  ...  ...
# 11104       0.0   SG
# 11105       0.0   SG
# 11106       0.0   SG
# 11107       0.0   SG
# 11108       0.0   SG
#
# [11109 rows x 17 columns]
