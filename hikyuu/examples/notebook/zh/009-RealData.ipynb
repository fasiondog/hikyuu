# %%
# %matplotlib inline
# %time from hikyuu.interactive import *
# Out:
# Initialize hikyuu_2.8.2_202609250345_RELEASE_macosx_arm64 ...
# 2026-09-25 13:39:21.368 [HKU-I] - current python version: 3.13.12 (main.cpp:77)
# 2026-09-25 13:39:22,563 [INFO] runing in interactive session [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:149) [hikyuu::hku_info]
# 2026-09-25 13:39:22,564 [INFO] running in jupyter [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:156) [hikyuu::hku_info]
# 2026-09-25 13:39:22.567 [HKU-I] - 插件路径: /Users/fasiondog/workspace/hku_plugin/hikyuu_plugin (StockManager.cpp:124)
# 2026-09-25 13:39:22.597 [HKU-I] - Using CLICKHOUSE BaseInfoDriver (BaseInfoDriver.cpp:56)
# 2026-09-25 13:39:22.622 [HKU-I] - 加载市场信息…… (StockManager.cpp:1050)
# 2026-09-25 13:39:22.633 [HKU-I] - 加载证券类型信息…… (StockManager.cpp:1067)
# 2026-09-25 13:39:22.646 [HKU-I] - 加载证券信息…… (StockManager.cpp:948)
# 2026-09-25 13:39:22.813 [HKU-I] - 加载权息数据…… (StockManager.cpp:1170)
# 2026-09-25 13:39:23.094 [HKU-I] - 加载板块信息…… (StockManager.cpp:214)
# 2026-09-25 13:39:23.213 [HKU-I] - 加载K线数据…… (StockManager.cpp:221)
# 2026-09-25 13:39:23.214 [HKU-I] - 预加载 day K线数据至缓存 (最大数量: 100000)! (StockManager.cpp:395)
# 2026-09-25 13:39:23.214 [HKU-I] - 0.61 秒数据加载完毕. (StockManager.cpp:231)
# CPU times: user 2.25 s, sys: 165 ms, total: 2.41 s
# Wall time: 3.1 s

# %% [markdown]
# # 获取实时日线数据
#
# 目前仅支持获取实时日线数据，使用函数 realtimeUpdate(source, delta=60)。其中，source支持 'qq' | 'qmt'，默认使用 qq
#
# **使用 qq 时，应注意控制两次获取数据之间的间隔时长（使用参数delta，默认时长60s），以免 ip 被 sina 或 qq 列入黑名单。**

# %%
# %time realtime_update('qq')
# Out:
# Update completed! Update time: 2026-09-25 13:39:24.276445
# CPU times: user 395 ms, sys: 99.9 ms, total: 495 ms
# Wall time: 994 ms
