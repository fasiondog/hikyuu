# %%
#%matplotlib inline
# %time from hikyuu.interactive import *

# %% [markdown]
# 1 全局获取股票对象
# ==========
#
# 1.1 获取股票对象
# -----------------
#
# 通过全局管理对象 sm，或使用函数 get_stock。股票标识格式“市场标识+股票代码”，市场标识：沪市sh，深市sz。

# %%
#s = getStock('sh000001')
s = sm['sh000001']
print(s)

# %% [markdown]
# 1.2 遍历所有股票
# -----------------

# %%
i = 0
# Traverse all the stocks
for s in sm:
    i += 1
    #print(s)
print("Total number:", i)

len(sm)

# %% [markdown]
# 2 通过板块（Block）遍历股票对象
# ================
#
# 通过 sm.get_stock("板块分类", "板块名称") 获取相应板块

# %%
blk = sm.get_block("指数板块", "沪深300")  # domain data: block names
print(len(blk))
# for s in blk:
#     if s.valid:
#         print(s)

# %% [markdown]
# 3 查看权息信息
# =======

# %%
ws = sm['sz000001'].get_weight()
for w in ws:
    print(w)

# %%
ws.to_df()
