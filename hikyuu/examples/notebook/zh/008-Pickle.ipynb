# %%
# %time from hikyuu.interactive import *
# Out:
# Initialize hikyuu_2.8.2_202609250345_RELEASE_macosx_arm64 ...
# 2026-09-25 13:39:07.133 [HKU-I] - current python version: 3.13.12 (main.cpp:77)
# 2026-09-25 13:39:08,527 [INFO] runing in interactive session [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:149) [hikyuu::hku_info]
# 2026-09-25 13:39:08,527 [INFO] running in jupyter [<module>] (/Users/fasiondog/workspace/hikyuu/hikyuu/__init__.py:156) [hikyuu::hku_info]
# 2026-09-25 13:39:08.531 [HKU-I] - 插件路径: /Users/fasiondog/workspace/hku_plugin/hikyuu_plugin (StockManager.cpp:124)
# 2026-09-25 13:39:08.561 [HKU-I] - Using CLICKHOUSE BaseInfoDriver (BaseInfoDriver.cpp:56)
# 2026-09-25 13:39:08.590 [HKU-I] - 加载市场信息…… (StockManager.cpp:1050)
# 2026-09-25 13:39:08.604 [HKU-I] - 加载证券类型信息…… (StockManager.cpp:1067)
# 2026-09-25 13:39:08.613 [HKU-I] - 加载证券信息…… (StockManager.cpp:948)
# 2026-09-25 13:39:08.753 [HKU-I] - 加载权息数据…… (StockManager.cpp:1170)
# 2026-09-25 13:39:08.932 [HKU-I] - 加载板块信息…… (StockManager.cpp:214)
# ...

# %%
k = get_kdata('sh000001', -100)

# %%
import pickle

with open("temp", 'wb') as f:
    pickle.dump(k, f)

# %%
hku_save(k, "temp")

# %%
k2 = hku_load("temp")

# %%
k2.plot()
